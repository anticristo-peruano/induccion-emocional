# %%
# -----------------------------------------------------------
# RL comparison on Spotify-like dataset: Q-Learning, Dynamic Q, SARSA
# Generates three separate plots (one per algorithm) showing
# "Episode vs. steps needed to reach a 'happy' song".
# -----------------------------------------------------------

from functions.reinforcement import *

yaml_path = 'parameters.yaml'

PIPELINE = [
    ("Q-Learning (α fixed)", trainer(yaml_path).reinforce(Q_LEARNING)),
    ("Dynamic Q-Learning (α=1/N)", trainer(yaml_path).reinforce(DYNAQ)),
    ("SARSA (α fixed)", trainer(yaml_path).reinforce(SARSA))
]

for title, steps in PIPELINE:
    plot_steps(title,steps)
